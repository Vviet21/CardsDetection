# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Deep_Learning_QT_Detect')

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone

# %%
cd yolov5
# Out:
# /content/drive/MyDrive/Colab Notebooks/Deep_Learning_QT_Detect/yolov5

# %%
# !python train.py --img 800 --batch 32 --epochs 100 --data cardss.yaml --weights yolov5s.pt --rect
# Out:
# train: weights=yolov5s.pt, cfg=, data=cardss.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=800, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2023-3-6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --source '/content/drive/MyDrive/Colab Notebooks/Deep_Learning_QT_Detect/yolov5/cardss/test/images/003787710_jpg.rf.6de5d45a15430bc03a899ade8f42b4bd.jpg' --weights best.pt --imgsz 800 --hide-conf
# Out:
# detect: weights=['best.pt'], source=/content/drive/MyDrive/Colab Notebooks/Deep_Learning_QT_Detect/yolov5/cardss/test/images/003787710_jpg.rf.6de5d45a15430bc03a899ade8f42b4bd.jpg, data=data/coco128.yaml, imgsz=[800, 800], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=True, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2023-3-6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7150369 parameters, 0 gradients, 16.2 GFLOPs
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots(figsize=(15, 10))
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([])
ax.axis('off')

file = '/content/drive/MyDrive/Colab Notebooks/Deep_Learning_QT_Detect/yolov5/runs/detect/exp8/003787710_jpg.rf.6de5d45a15430bc03a899ade8f42b4bd.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(show_img)
